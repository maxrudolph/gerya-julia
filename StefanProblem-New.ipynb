# %%
# Importing (using/include) packages and files needed for the code to run
using SparseArrays
using LinearAlgebra
using IterativeSolvers
using WriteVTK
using Printf
using Statistics
using Dates
using SpecialFunctions
using Roots
using NLsolve
using Printf
using HDF5
include("Grid.jl")
include("Markers.jl")
include("Stokes.jl")
include("GridOperations.jl")
include("Topo.jl")
# Note: that we import pyplot last to avoid a name conflict with grid
using PyPlot
include("Visualization.jl")
# Out:
# plots (generic function with 1 method)

# %% [markdown]
# # Stefan Problem - test melting and solidification
#
# Step 1 - import packages

# %% [markdown]
# Step 2 - Define a function that relates entropy and temperature/pressure.
# $$
# T = f_1(P,S)
# $$
#
# $$
# T = \exp \left( \frac{S}{C_V} + \ln (T_{ref}) - \frac{\Delta H_{fus} }{C_V T_M}X \right)
# $$
#
# and
# $$
# S = f_2(P,T)
# $$
# $$
# S = C_V (\ln (T) - \ln(T_{ref})) + \frac{\Delta H_{fus}}{T_m}X
# $$

# %%
# functions that relates entropy and temperature/pressure are define in TemperatureEntropy.jl file
include("TemperatureEntropy.jl")
# Out:
# subgirdSdiff! (generic function with 1 method)

# %% [markdown]
# Step 3 - Write functions to set up the initial condition for the Stefan problem
#
# - Consider a box with width 100 km and height 100 km.
# - The box is filled entirely with one material
# - Initially, the top 10 km is solid and the bottom 90 km is liquid.
# - The sides are insulating
# - Density is constant and equal to 1000 kg/m$^3$
# - The surface is at T=100K, the bottom is at T=273 K
# - The liquid is isothermal with $T=T_m$.
# - The solid has initial $T(z)$ given by the Stefan solution (Turcotte and Schubert section 4.18)
# $$
# \theta = \frac{erf(\eta)}{erf(\lambda_1)}
# $$
# - Given the initial temperature, compute initial entropy S on the markers.

# %%
function initial_ice_depth(x::Float64)
    return options["ym"]
end 

struct Materials
    alpha::Vector{Float64} # Thermal expansion (1/K)
    rho0::Vector{Float64} # Density (kg/m^3)
    Hr::Vector{Float64} # Radiogenic heat production (W/m^3)
    Cp::Vector{Float64} # Heat capacity (J/kg*K)
    kThermal::Vector{Float64} # Thermal conductivity (W/m*K)
    function Materials()
        new([0.0],[1e3],[0.0],[2.1e3],[2.2])
    end    
end

function update_marker_prop!(markers::Markers,materials::Materials)
    rho = markers.scalarFields["rho"]
    T = markers.scalarFields["T"]
    X = markers.scalarFields["X"]
    S = markers.scalarFields["S"]
    mmat = markers.integers[markers.integerFields["material"],:]
    for i in 1:markers.nmark
        markers.scalars[rho,i] = materials.rho0[mmat[i]]
    end
end

function update_marker_T_X!(markers::Markers,materials::Materials,options::Dict)
    T = markers.scalarFields["T"]
    X = markers.scalarFields["X"]
    S = markers.scalarFields["S"]    
    for i in 1:markers.nmark
        markers.scalars[T,i],markers.scalars[X,i] = compute_T_X_from_S((markers.scalars[S,i]),options)
    end
end

function initial_conditions!(markers::Markers,materials::Materials,options::Dict)
    material = markers.integerFields["material"]
    S = markers.scalarFields["S"]
    X = markers.scalarFields["X"]
    T = markers.scalarFields["T"]
    alpha = markers.scalarFields["alpha"]
    Cp = markers.scalarFields["Cp"]
    Hr = markers.scalarFields["Hr"]
    kThermal = markers.scalarFields["kThermal"]
    
    # Setting up Stefan conidtion
    lambda1 = get_lambda1(options)
    t = get_t(lambda1,options)
    
    # Note: the melt fraction is defining our layers or ice and water.
    # water - X = 1.0 
    # ice - X = 0.0
    for i in 1:markers.nmark
        mx = markers.x[1,i]
        my = markers.x[2,i]
        hice = initial_ice_depth(mx)
        
        if my > hice # subsurface global ocean
            markers.integers[material,i] = 1
            markers.scalars[alpha,i] = materials.alpha[1]
            markers.scalars[Cp,i] = materials.Cp[1]
            markers.scalars[Hr,i] = materials.Hr[1]
            markers.scalars[kThermal,i] = materials.kThermal[1]
            markers.scalars[T,i] = 273.0
            markers.scalars[X,i] = 1.0
            markers.scalars[S,i] = compute_S_from_T_X(markers.scalars[X,i],markers.scalars[T,i],options)

        elseif my < hice # icy shell
            markers.integers[material,i] = 1
            markers.scalars[alpha,i] = materials.alpha[1]
            markers.scalars[Cp,i] = materials.Cp[1]
            markers.scalars[Hr,i] = materials.Hr[1]
            markers.scalars[kThermal,i] = materials.kThermal[1]
            markers.scalars[T,i] = stefan_initial_condition(get_theta(my,t,lambda1),options)
            markers.scalars[X,i] = 0.0
            markers.scalars[S,i] = compute_S_from_T_X(markers.scalars[X,i],markers.scalars[T,i],options)
        end
    end 
    # end loop over markers
    update_marker_prop!(markers,materials)
end

function get_interface(grid::CartesianGrid,mat::Matrix{Float64},contour_value::Float64)
    # Finding interfaces
    interface_position = zeros(Float64,grid.nx+1);
    for j in 1:grid.nx+1
        i = 1
        while i <= grid.ny
            if mat[i,j] == contour_value
                interface_position[j] = grid.yc[i]
                break
            elseif mat[i+1,j] < contour_value
                # interface is located within this cell.
                interface_position[j] = grid.yc[i] + ((grid.yc[i+1]-grid.yc[i])/(mat[i+1,j]-mat[i,j]))*(contour_value-mat[i,j])
                break
            end
            i = i+1
        end
    end
    return interface_position
end
# Out:
# get_interface (generic function with 1 method)

# %% [markdown]
# # Main part of code
# - At each timestep, begin by computing T(S,X) on the markers
# - Iteratively solve the temperature equation. Start with a guess S_new = S_old
#     - For T_new, compute $q_{cond} = \nabla \cdot (k \nabla T_{new})$
#     - Solve diffusion equation for S_new
#     - Given S_new, update T_new
#     - Iterate until converged...
# - Given the new entropy solution on the cell centers, update the entropy and melt fraction on the markers.

# %%
function model_run(options::Dict)
    W = 1e4
    H = 2e4
    ny = 50
    nx = 51 
    gx = 0.0
    gy = 0.113
    
    # -1 = insulating, 1 = constant temp 
    Tbctype = [-1,-1,1,1] #left, right, top, bottom
    Tbcval = [0.0,0.0,100.0,273.0] #left, right, top, bottom
    markx = 6
    marky = 6
    seconds_in_year = 3.15e7
    # plot interval should be in seconds
    plot_interval = 1e6*seconds_in_year # 1 Myr 
    
    end_time = 3e7*seconds_in_year
    dtmax = plot_interval
    grid = CartesianGrid(W,H,nx,ny)
    println("Grid resolution(ny x nx) : $ny x $nx")
    println("Cell size in the x-direction is $(grid.W/(grid.nx-1))")
    println("Cell size in the y-direction is $(grid.H/(grid.ny-1))")
    
    materials = Materials()
    println("Creating Markers...")
    @time markers = Markers(grid,["alpha","T","rho","Cp","Hr","kThermal","S","X"],["material"] ; nmx=markx,nmy=marky,random=false)
    println("Initial condition...")
    @time initial_conditions!(markers,materials,options)

    local time_plot = []
    local X_contour = []
    local X_contour_array = []
    
    ### Setting up agruments for termination criteria ###
    max_step::Int64=-1
    max_time::Float64=-1
    max_time = max_time == -1.0 ? typemax(Float64) : max_time
    max_step = max_step == -1 ? typemax(Int64) : max_step

    time = 0.0
    iout= 0
    last_plot = 0.0
    dt = dtmax
    
    rho_c = nothing
    kThermal_vx = nothing
    kThermal_vy = nothing
    Hr = nothing
    kThermal = nothing
    dTmax = nothing
    dTemp = nothing
    Tnew = nothing
    Tlast = nothing
    Snew = nothing
    Slast = nothing
    Xnew = nothing
    Xlast = nothing
    q_vx = nothing
    q_vy = nothing
    melt_fraction_contour = nothing
    
    itime = 1 
    output_dir = "debugging"
    terminate = false
    while !terminate
        
        update_marker_prop!(markers,materials)
        rho_c_new,Hr_new,kThermal_new,Slast_new,Xlast_new, = marker_to_stag(markers,grid,["rho","Hr","kThermal","S","X"],"center")
        rhocp = markers.scalars[markers.scalarFields["rho"],:] .* markers.scalars[markers.scalarFields["Cp"],:]
        Tlast_new, = marker_to_stag(markers,grid,["T"],"center",extra_weight = rhocp)
        kThermal_vx_new, = marker_to_stag(markers,grid,["kThermal",],"vx")
        kThermal_vy_new, = marker_to_stag(markers,grid,["kThermal",],"vy")
        
        # deal with any NaN values from interpolation:
        if itime > 1
            replace_nan!(rho_c,rho_c_new)
            replace_nan!(kThermal_vx,kThermal_vx_new)
            replace_nan!(kThermal_vy,kThermal_vy_new)
            replace_nan!(Hr,Hr_new)
            replace_nan!(kThermal,kThermal_new)
            replace_nan!(Tlast,Tlast_new)
            replace_nan!(Slast,Slast_new)
            replace_nan!(Xlast,Xlast_new)
        end
        # Copy field data
        rho_c = copy(rho_c_new)
        kThermal_vx = copy(kThermal_vx_new)
        kThermal_vy = copy(kThermal_vy_new)
        Hr = copy(Hr_new)
        kThermal = copy(kThermal_new)
        Tlast = copy(Tlast_new)    
        Slast = copy(Slast_new)
        Xlast = copy(Xlast_new)
        
        # Tlast,Xlast = update_T_X_from_S(Slast,options)
        # Tlast,Xlast,Slast = ghost_nodes_center_TXS(grid,Tlast,Xlast,Slast,Tbctype,Tbcval,options) 
        
        # Initial guess for S
        Snew = copy(Slast)
        # Initial guess for T
        Tnew,Xnew = update_T_X_from_S(Snew,options)
        Tnew,Xnew,Snew = ghost_nodes_center_TXS(grid,Tnew,Xnew,Slast,Tbctype,Tbcval,options)

        diffusion_timestep = calculate_diffusion_timestep(grid,options)
        if itime > 1
            this_dtmax = min(1.2*dt,dtmax)
        else
            this_dtmax = dtmax
        end
        if this_dtmax > diffusion_timestep
            dt = diffusion_timestep
        else 
            dt = this_dtmax
        end

        last_T_norm = NaN
        T_norm = NaN
        dT = nothing
        dTmax = Inf
        dS = nothing
        dSmax = Inf
        tolerance = 1e-8
        dTnorm = []
        ititer = []
        titer = 1 
        max_titer = 300
        for titer=1:max_titer
            
            # Computing conductive heat flux
            q_vx,q_vy = compute_q_cond(grid,Tlast,kThermal_vx,kThermal_vy) # W/m^2
            
            # Computing the new entropy
            Snew = compute_S_new(grid,Tnew,rho_c,Hr,q_vx,q_vy,Slast,dt);
    
            # Updating the new temperature and new melt fraction from the new entropy
            Tnew,Xnew = update_T_X_from_S(Snew,options)             
            Tnew,Xnew,Snew = ghost_nodes_center_TXS(grid,Tnew,Xnew,Snew,Tbctype,Tbcval,options)
       
            if titer > 1
                last_T_norm = T_norm;
                T_norm = norm(Tnew[2:grid.ny,2:grid.nx]);
                push!(dTnorm,abs(T_norm-last_T_norm))
                push!(ititer,titer)
            else
                T_norm = norm(Tnew[2:end-1,2:end-1]);
                push!(dTnorm,abs(T_norm-last_T_norm))
                push!(ititer,titer)
            end
            
            # Computing the maximum temperature change
            dT = Tnew - Tlast
            dTmax = maximum(abs.(dT[2:grid.ny,2:grid.nx]))

            # Computing the maximum entropy change
            dS = Snew - Slast
            dSmax = maximum(abs.(dS[2:grid.ny,2:grid.nx]))

            # Checking for convergence:
            if titer > 1 && abs(T_norm-last_T_norm) < tolerance
                # println("Converged after $titer iterations.")
                break
            elseif titer == max_titer
                terminate = true
                @error("Did not converged")
            iout += 1
            elseif any(isnan.(dT))
                terminate = true
                @error("NaN or Inf apperred")
            end
        end
        
        
        # Updating entropy on the markers by projecting dS from the cell centers to the markers
        cell_center_to_markers!(markers,grid,Snew,"S")
        update_marker_T_X!(markers,materials,options)
        
        melt_fraction_contour = get_interface(grid,-Xnew,-0.5)
        append!(X_contour_array,[melt_fraction_contour])
        avg_melt_fraction_contour = mean(melt_fraction_contour)
        append!(X_contour,avg_melt_fraction_contour)
        append!(time_plot,time)  

        # Checking Termination Criteria, time is in Myr, amplitude is in meters
        if time >= max_time || itime >= max_step || (X_contour[itime] - X_contour[1]) > 5e3
            terminate = true
            figure()
            title(L"Melt\,Fraction")
            cs = contour(grid.xc/1e3,grid.yc/1e3,Xnew,[0.5],colors="red")
            clabel(cs,inline=true,fontsize=8,fmt="Solidification boundary")
            pcolor(grid.xc/1e3,grid.yc/1e3,Xnew)
            colorbar(cmap="viridis")
            gca().set_ylabel(L"Height\,(km)")
            gca().set_xlabel(L"Width\,(km)")
            gca().invert_yaxis()
            gca().set_aspect("equal")
            tight_layout()
            show() 
        end

        if time == 0.0 || mod(itime,10) == 0 || terminate
            last_plot = time 
            # Markers output
            name1 = @sprintf("%s/markers.%04d.vtp",output_dir,iout)
            println("Writing visualization file = ",name1)
            visualization(markers,time/seconds_in_year;filename=name1)
            iout += 1
        end

        time += dt
        if mod(itime,100) == 0
            println("Ice shell as thicken by ",(X_contour[itime] - X_contour[1])/1e3,"km")
            println("time = ",time/seconds_in_year," yr, ",time/seconds_in_year/1e3," Kyr, ",time/seconds_in_year/1e6," Myr") 
        end
        itime += 1
    end
    return grid,time_plot,X_contour_array,X_contour,itime
end
# Out:
# model_run (generic function with 1 method)

# %%
options = Dict()
options["latent heat of fusion"] = 3.34e5 #J/kg
options["specific heat of ice"] = 2.1e3 # J/kg*K (ice)
options["density of ice"] = 1e3 # kg/m^3
options["thermal conductivity of ice"] = 2.2 # W/m*K
options["thermal diffusivity"] = options["thermal conductivity of ice"] / (options["density of ice"]*options["specific heat of ice"]) # m^2/s
options["Tm"] = 273.0 # K
options["To"] = 100.0 # K
options["ym"] = 1e4 # m 
grid,time_plot,X_contour_array,X_contour,itime = model_run(options);
# Out:
# Grid resolution(ny x nx) : 50 x 51
# Cell size in the x-direction is 200.0
# Cell size in the y-direction is 408.16326530612247
# Creating Markers...
#   0.001863 seconds (19 allocations: 9.893 MiB)
# Initial condition...
#   0.096224 seconds (1.89 M allocations: 29.109 MiB, 6.49% gc time, 3.78% compilation time)
# Writing visualization file = debugging/markers.0000.vtp
#   0.000785 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0001.vtp
#   0.000787 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0002.vtp
#   0.000926 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0003.vtp
#   0.000899 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0004.vtp
#   0.000762 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0005.vtp
#   0.000771 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0006.vtp
#   0.000751 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0007.vtp
#   0.000945 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0008.vtp
#   0.000746 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0009.vtp
#   0.000759 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0010.vtp
#   0.003602 seconds (2 allocations: 1.346 MiB, 76.75% gc time)
# Ice shell as thicken by 0.46523519027644944km
# time = 12121.212121212135 yr, 12.121212121212135 Kyr, 0.012121212121212135 Myr
# Writing visualization file = debugging/markers.0011.vtp
#   0.000753 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0012.vtp
#   0.000752 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0013.vtp
#   0.000923 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0014.vtp
#   0.000941 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0015.vtp
#   0.003619 seconds (2 allocations: 1.346 MiB, 77.70% gc time)
# Writing visualization file = debugging/markers.0016.vtp
#   0.000753 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0017.vtp
#   0.000740 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0018.vtp
#   0.000757 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0019.vtp
#   0.000744 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0020.vtp
#   0.003631 seconds (2 allocations: 1.346 MiB, 77.37% gc time)
# Ice shell as thicken by 0.9228483765510155km
# time = 24242.424242424164 yr, 24.242424242424164 Kyr, 0.024242424242424163 Myr
# Writing visualization file = debugging/markers.0021.vtp
#   0.000788 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0022.vtp
#   0.000757 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0023.vtp
#   0.000770 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0024.vtp
#   0.000747 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0025.vtp
#   0.003691 seconds (2 allocations: 1.346 MiB, 77.48% gc time)
# Writing visualization file = debugging/markers.0026.vtp
#   0.000783 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0027.vtp
#   0.000994 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0028.vtp
#   0.000775 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0029.vtp
#   0.000270 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0030.vtp
#   0.000763 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 1.3686327331503927km
# time = 36363.636363636164 yr, 36.36363636363616 Kyr, 0.03636363636363616 Myr
# Writing visualization file = debugging/markers.0031.vtp
#   0.000830 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0032.vtp
#   0.000753 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0033.vtp
#   0.000755 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0034.vtp
#   0.000139 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0035.vtp
#   0.000761 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0036.vtp
#   0.000772 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0037.vtp
#   0.000768 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0038.vtp
#   0.000743 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0039.vtp
#   0.003981 seconds (2 allocations: 1.346 MiB, 78.62% gc time)
# Writing visualization file = debugging/markers.0040.vtp
#   0.000768 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 1.8020756426251028km
# time = 48484.848484848495 yr, 48.48484848484849 Kyr, 0.04848484848484849 Myr
# Writing visualization file = debugging/markers.0041.vtp
#   0.003817 seconds (2 allocations: 1.346 MiB, 78.58% gc time)
# Writing visualization file = debugging/markers.0042.vtp
#   0.000764 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0043.vtp
#   0.000782 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0044.vtp
#   0.000933 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0045.vtp
#   0.000740 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0046.vtp
#   0.004008 seconds (2 allocations: 1.346 MiB, 74.71% gc time)
# Writing visualization file = debugging/markers.0047.vtp
#   0.000729 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0048.vtp
#   0.000767 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0049.vtp
#   0.000824 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0050.vtp
#   0.003896 seconds (2 allocations: 1.346 MiB, 78.73% gc time)
# Ice shell as thicken by 2.225433981430631km
# time = 60606.060606060826 yr, 60.60606060606083 Kyr, 0.06060606060606082 Myr
# Writing visualization file = debugging/markers.0051.vtp
#   0.000756 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0052.vtp
#   0.000749 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0053.vtp
#   0.000782 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0054.vtp
#   0.000765 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0055.vtp
#   0.000745 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0056.vtp
#   0.000754 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0057.vtp
#   0.000767 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0058.vtp
#   0.000742 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0059.vtp
#   0.000759 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0060.vtp
#   0.000754 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 2.6442109409208534km
# time = 72727.27272727297 yr, 72.72727272727296 Kyr, 0.07272727272727297 Myr
# Writing visualization file = debugging/markers.0061.vtp
#   0.000764 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0062.vtp
#   0.000749 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0063.vtp
#   0.000743 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0064.vtp
#   0.000760 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0065.vtp
#   0.000766 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0066.vtp
#   0.000773 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0067.vtp
#   0.000783 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0068.vtp
#   0.000754 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0069.vtp
#   0.000756 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0070.vtp
#   0.000940 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 3.066028747389384km
# time = 84848.48484848453 yr, 84.84848484848453 Kyr, 0.08484848484848453 Myr
# Writing visualization file = debugging/markers.0071.vtp
#   0.000749 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0072.vtp
#   0.000845 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0073.vtp
#   0.000734 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0074.vtp
#   0.000803 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0075.vtp
#   0.001218 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0076.vtp
#   0.001034 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0077.vtp
#   0.000755 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0078.vtp
#   0.000802 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0079.vtp
#   0.001054 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0080.vtp
#   0.001194 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 3.4991738877496044km
# time = 96969.69696969609 yr, 96.96969696969609 Kyr, 0.09696969696969608 Myr
# Writing visualization file = debugging/markers.0081.vtp
#   0.000820 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0082.vtp
#   0.000978 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0083.vtp
#   0.000768 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0084.vtp
#   0.000768 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0085.vtp
#   0.000809 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0086.vtp
#   0.000805 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0087.vtp
#   0.000976 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0088.vtp
#   0.000773 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0089.vtp
#   0.001004 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0090.vtp
#   0.000807 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 3.9523323121815737km
# time = 109090.90909090765 yr, 109.09090909090764 Kyr, 0.10909090909090764 Myr
# Writing visualization file = debugging/markers.0091.vtp
#   0.000778 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0092.vtp
#   0.000882 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0093.vtp
#   0.000776 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0094.vtp
#   0.000796 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0095.vtp
#   0.000952 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0096.vtp
#   0.000752 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0097.vtp
#   0.000764 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0098.vtp
#   0.000779 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0099.vtp
#   0.000769 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0100.vtp
#   0.000949 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 4.4347944328938596km
# time = 121212.12121211921 yr, 121.21212121211921 Kyr, 0.1212121212121192 Myr
# Writing visualization file = debugging/markers.0101.vtp
#   0.000750 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0102.vtp
#   0.000932 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0103.vtp
#   0.000749 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0104.vtp
#   0.000927 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0105.vtp
#   0.000953 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0106.vtp
#   0.000750 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0107.vtp
#   0.000945 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0108.vtp
#   0.000775 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0109.vtp
#   0.000757 seconds (2 allocations: 1.346 MiB)
# Writing visualization file = debugging/markers.0110.vtp
#   0.000847 seconds (2 allocations: 1.346 MiB)
# Ice shell as thicken by 4.962499509361002km
# time = 133333.33333333075 yr, 133.33333333333076 Kyr, 0.13333333333333075 Myr
# Writing visualization file = debugging/markers.0111.vtp
#   0.000507 seconds (2 allocations: 1.346 MiB)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# Profile of ice-water inferface topograpgy over time from melt fraction
figure()
for i in 1:100:itime-1
    plot(grid.xc/1e3,X_contour_array[i]/1e3,label=(L"At",@sprintf("%.3g",time_plot[i]/3.15e7/1e6),L"Myr"))
end
title(L"Position\,\,of\,\,Solidified\,\,Layer\,\,Over\,\,Time")
gca().invert_yaxis()
# Legend is at the bottom
legend(loc="upper center",bbox_to_anchor=(0.5,-0.15),ncol=5)
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
lambda1 = get_lambda1(options)
t = get_t(lambda1,options)
y = get_y.(lambda1,time_plot.+t,Ref(options))
figure()
plot(time_plot/3.15e7/1e6,y/1e3,"b-",label="Stefan Solution")
# plot(time_plot/3.15e7/1e6,S_contour/1e3,"r--",label="Numerical Solution from Entropy contour")
plot(time_plot/3.15e7/1e6,X_contour/1e3,"r--",label="Numerical Solution from Melt Fraction contour")
gca().set_ylabel(L"Ice\,Thickness\,(km)")
gca().set_xlabel(L"Time\,(Myr)")
legend(loc="upper center",bbox_to_anchor=(0.5,-0.15),ncol=5)
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
# # # Profile of ice-water inferface topograpgy over time from melt fraction
# figure()
# for i in 1:1:itime-1
#     plot(grid.xc/1e3,X_contour_array[i]/1e3,label=(L"At",@sprintf("%.3g",time_plot[i]/3.15e7/1e6),L"Myr"))
# end
# title(L"Position\,\,of\,\,Solidified\,\,Layer\,\,Over\,\,Time")
# gca().invert_yaxis()
# # Legend is at the bottom
# legend(loc="upper center",bbox_to_anchor=(0.5,-0.15),ncol=5)
# show()
