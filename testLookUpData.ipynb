# %% [markdown]
# # Opening HDF5 File

# %%
using HDF5
using PyPlot

fname = "SeaFreeze_table_with_density.hdf5"
# Displaying all of the file's information
fid = h5open(fname, "r")
# Out:
# 🗂️ HDF5.File: (read-only) SeaFreeze_table_with_density.hdf5
# ├─ 📂 Density
# │  ├─ 🔢 Data
# │  ├─ 🔢 Dimensions
# │  ├─ 🔢 Elements
# │  ├─ 🔢 Shape
# │  ├─ 🔢 TypeofElements
# │  └─ 🔢 TypeofObject
# ├─ 📂 Entropy
# │  ├─ 🔢 Data
# │  ├─ 🔢 Dimensions
# │  ├─ 🔢 Elements
# │  ├─ 🔢 Shape
# │  ├─ 🔢 TypeofElements
# │  └─ 🔢 TypeofObject
# ├─ 📂 Pressure
# │  ├─ 🔢 Data
# │  ├─ 🔢 Dimensions
# │  ├─ 🔢 Elements
# │  ├─ 🔢 Shape
# │  ├─ 🔢 TypeofElements
# │  └─ 🔢 TypeofObject
# └─ 📂 Temperature
#    ├─ 🔢 Data
#    ├─ 🔢 Dimensions
#    ├─ 🔢 Elements
#    ├─ 🔢 Shape
#    ├─ 🔢 TypeofElements
#    └─ 🔢 TypeofObject

# %%
# Reading Data from file
entropy = fid["Entropy"];
pressure = fid["Pressure"];
temperature = fid["Temperature"];
density = fid["Density"];

# %%
# Displaying the contents in Entropy group 
for obj in entropy
  data = read(obj)
  display(data)
end

# Accessing Entropy contents that I want
ed = read(entropy, "Data");
# Out:
# 21×225 Matrix{Float64}:
#  -2830.02  -2821.11  -2812.2   …  336.957  351.061  365.116  379.123
#  -2830.16  -2821.26  -2812.36     334.534  348.541  362.501  376.415
#  -2830.31  -2821.41  -2812.51     331.999  345.917  359.789  373.617
#  -2830.45  -2821.56  -2812.67     329.358  343.193  356.984  370.731
#  -2830.59  -2821.7   -2812.82     326.617  340.375  354.09   367.763
#  -2830.72  -2821.84  -2812.96  …  323.781  337.468  351.113  364.716
#  -2830.86  -2821.98  -2813.11     320.855  334.477  348.057  361.595
#  -2830.99  -2822.12  -2813.25     317.846  331.406  344.926  358.404
#  -2831.12  -2822.25  -2813.39     314.758  328.262  341.725  355.148
#  -2831.25  -2822.39  -2813.53     311.596  325.048  338.459  351.83
#  -3007.99  -2998.39  -2988.79  …  308.365  321.768  335.132  348.455
#  -3008.47  -2998.87  -2989.29     305.07   318.429  331.748  345.027
#  -3008.95  -2999.36  -2989.78     301.715  315.033  328.311  341.549
#  -3009.43  -2999.84  -2990.27     298.304  311.584  324.825  338.025
#  -3009.9   -3000.32  -2990.75     294.843  308.088  321.293  334.459
#  -3010.37  -3000.8   -2991.23  …  291.333  304.547  317.72   330.853
#  -3010.84  -3001.27  -2991.72     287.78   300.964  314.107  327.211
#  -3011.31  -3001.75  -2992.19     284.186  297.343  310.459  323.535
#  -3011.77  -3002.22  -2992.67     280.555  293.686  306.777  319.828
#  -3012.23  -3002.68  -2993.14     276.889  289.997  303.065  316.092
#  -3012.69  -3003.15  -2993.61  …  273.191  286.278  299.324  312.33
# "No. of dimensions: 2"
# "Total number of elements: 4725"
# "Shape of array(row,col): (225, 21)"
# "Array stores elements of type: float64"
# "Array is of type: <class 'numpy.ndarray'>"

# %%
# Displaying the data in Pressure group 
for obj in pressure
  data = read(obj)
  display(data)
end

# Accessing Pressure content that I want
pd = read(pressure, "Data");
# Out:
# 21-element Vector{Float64}:
#    0.0
#   10.0
#   20.0
#   30.0
#   40.0
#   50.0
#   60.0
#   70.0
#   80.0
#   90.0
#  100.0
#  110.0
#  120.0
#  130.0
#  140.0
#  150.0
#  160.0
#  170.0
#  180.0
#  190.0
#  200.0
# "No. of dimensions: 1"
# "Total number of elements: 21"
# "Shape of array(row,col): (21,)"
# "Array stores elements of type: float64"
# "Array is of type: <class 'numpy.ndarray'>"

# %%
# Displaying the data in Temperature group 
for obj in temperature
  data = read(obj)
  display(data)
end

# Accessing Temperature content that I want
td = read(temperature, "Data");
# Out:
# 225-element Vector{Float64}:
#   75.0
#   76.0
#   77.0
#   78.0
#   79.0
#   80.0
#   81.0
#   82.0
#   83.0
#   84.0
#   85.0
#   86.0
#   87.0
#    ⋮
#  288.0
#  289.0
#  290.0
#  291.0
#  292.0
#  293.0
#  294.0
#  295.0
#  296.0
#  297.0
#  298.0
#  299.0
# "No. of dimensions: 1"
# "Total number of elements: 225"
# "Shape of array(row,col): (225,)"
# "Array stores elements of type: float64"
# "Array is of type: <class 'numpy.ndarray'>"

# %%
# Displaying the data in Density group 
for obj in density
  data = read(obj)
  display(data)
end

# Accessing Density content that I want
rhod = read(density, "Data");
# Out:
# 21×225 Matrix{Float64}:
#   933.542   933.529   933.515   933.501  …   997.29   997.04   996.781
#   934.425   934.412   934.399   934.385     1001.77  1001.51  1001.24
#   935.302   935.29    935.276   935.263     1006.16  1005.88  1005.6
#   936.174   936.161   936.148   936.135     1010.45  1010.17  1009.87
#   937.039   937.027   937.014   937.0       1014.67  1014.37  1014.06
#   937.898   937.886   937.874   937.86   …  1018.79  1018.48  1018.17
#   938.752   938.74    938.728   938.715     1022.84  1022.52  1022.19
#   939.6     939.588   939.576   939.563     1026.81  1026.48  1026.14
#   940.442   940.43    940.418   940.406     1030.7   1030.36  1030.02
#   941.278   941.267   941.255   941.242     1034.52  1034.17  1033.82
#  1193.1    1193.03   1192.96   1192.89   …  1038.27  1037.91  1037.55
#  1193.91   1193.84   1193.77   1193.7       1041.95  1041.58  1041.21
#  1194.71   1194.64   1194.57   1194.5       1045.56  1045.19  1044.81
#  1195.51   1195.44   1195.37   1195.3       1049.11  1048.73  1048.34
#  1196.31   1196.24   1196.17   1196.1       1052.6   1052.21  1051.82
#  1197.1    1197.03   1196.96   1196.9    …  1056.03  1055.63  1055.23
#  1197.89   1197.83   1197.76   1197.69      1059.4   1059.0   1058.59
#  1198.68   1198.62   1198.55   1198.48      1062.72  1062.31  1061.89
#  1199.47   1199.4    1199.33   1199.27      1065.98  1065.56  1065.14
#  1200.25   1200.19   1200.12   1200.05      1069.19  1068.77  1068.34
#  1201.03   1200.97   1200.9    1200.83   …  1072.35  1071.92  1071.49
# "No. of dimensions: 2"
# "Total number of elements: 4725"
# "Shape of array(row,col): (225, 21)"
# "Array stores elements of type: float64"
# "Array is of type: <class 'numpy.ndarray'>"

# %% [markdown]
# # Closing HDF5 File

# %%
# Close file
close(fid)

# %%
display(ed)
# Out:
# 21×225 Matrix{Float64}:
#  -2830.02  -2821.11  -2812.2   …  336.957  351.061  365.116  379.123
#  -2830.16  -2821.26  -2812.36     334.534  348.541  362.501  376.415
#  -2830.31  -2821.41  -2812.51     331.999  345.917  359.789  373.617
#  -2830.45  -2821.56  -2812.67     329.358  343.193  356.984  370.731
#  1200.25   1200.19   1200.12   1200.05      1069.19  1068.77  1068.34
#  1201.03   1200.97   1200.9    1200.83   …  1072.35  1071.92  1071.49

# %%
using Interpolations

# %%
entropy = ed;
density = rhod;
pressure = pd*1e6;
temperature = td;

# linear interpolation for entropy
interp_linear1 = linear_interpolation((pressure,temperature),entropy)

output1 = zeros(size(entropy))
    
for i=1:size(temperature,1)
    for j=1:size(pressure,1)
        output1[j,i]=interp_linear1(pressure[j],temperature[i])
    end
end


# linear interpolation for density
interp_linear2 = linear_interpolation((pressure,temperature),density)

output2 = zeros(size(density))
    
for i=1:size(temperature,1)
    for j=1:size(pressure,1)
        output2[j,i]=interp_linear2(pressure[j],temperature[i])
    end
end

# %%
figure()
pcolor(temperature,pressure,output1-ed,cmap=get_cmap("viridis"))
title(L"Linear\,\,Interpolation\,\,for\,\,Entropy")
colorbar(label=L"Entropy\,(J/K/kg)")
gca().set_xlabel(L"Temperature\,(K)")
gca().set_ylabel(L"Pressure\,(Pa)")
gca().spines["top"].set_visible(false) # Hide the top edge of the axis
gca().spines["right"].set_visible(false) # Hide the right edge of the axis
gca().xaxis.set_ticks_position("bottom")
gca().yaxis.set_ticks_position("left")
gca().spines["left"].set_position(("axes",-0.03)) # Offset the left scale from the axis
gca().spines["bottom"].set_position(("axes",-0.03)) # Offset the bottom scale from the axis
show()

figure()
pcolor(temperature,pressure,output2-rhod,cmap=get_cmap("viridis"))
title(L"Linear\,\,Interpolation\,\,for\,\,Density")
colorbar(label=L"Density\,(kg/m^{3})")
gca().set_xlabel(L"Temperature\,(K)")
gca().set_ylabel(L"Pressure\,(Pa)")
gca().spines["top"].set_visible(false) # Hide the top edge of the axis
gca().spines["right"].set_visible(false) # Hide the right edge of the axis
gca().xaxis.set_ticks_position("bottom")
gca().yaxis.set_ticks_position("left")
gca().spines["left"].set_position(("axes",-0.03)) # Offset the left scale from the axis
gca().spines["bottom"].set_position(("axes",-0.03)) # Offset the bottom scale from the axis
show()
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
maximum(output1-ed)
# Out:
# 0.0

# %%
maximum(output2-rhod)
# Out:
# 0.0

# %%
figure()
pcolormesh(temperature,pressure,density,cmap=get_cmap("viridis"),shading="gouraud")
colorbar(label=L"Density\,(kg/m^{3})")
gca().set_xlabel(L"Temperature\,(K)")
gca().set_ylabel(L"Pressure\,(Pa)")
gca().spines["top"].set_visible(false) # Hide the top edge of the axis
gca().spines["right"].set_visible(false) # Hide the right edge of the axis
gca().xaxis.set_ticks_position("bottom")
gca().yaxis.set_ticks_position("left")
gca().spines["left"].set_position(("axes",-0.03)) # Offset the left scale from the axis
gca().spines["bottom"].set_position(("axes",-0.03)) # Offset the bottom scale from the axis
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
figure()
pcolormesh(temperature,pressure,entropy,cmap=get_cmap("inferno"),shading="gouraud")
colorbar(label=L"Entropy\,(J/K/kg)")
gca().set_xlabel(L"Temperature\,(K)")
gca().set_ylabel(L"Pressure\,(Pa)")
gca().spines["top"].set_visible(false) # Hide the top edge of the axis
gca().spines["right"].set_visible(false) # Hide the right edge of the axis
gca().xaxis.set_ticks_position("bottom")
gca().yaxis.set_ticks_position("left")
gca().spines["left"].set_position(("axes",-0.03)) # Offset the left scale from the axis
gca().spines["bottom"].set_position(("axes",-0.03)) # Offset the bottom scale from the axis
show()
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
interp_linear1[1,100]

# %%
interp_linear1(1,100)
